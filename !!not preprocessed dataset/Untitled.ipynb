# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('PlayingCards_52.png')
image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
im_bw = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)

# %%
thresh, im_bw = cv2.threshold(im_bw, 170, 255, 0)

# %%
contours, hierarchy = cv2.findContours(im_bw.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
rects = [cv2.minAreaRect(each) for each in contours]
rects = [(a,b,c) for a, b, c  in rects if ((b[0]*b[1]>5000))]

# %%
len(rects)
# Out:
# 52

# %%
img = image.copy()

# %%
for i in rects:
    box = cv2.boxPoints(i)
    box = box.astype('int')
    img = cv2.drawContours(img, [box], -1, (255,255,0), 4)

# %%
rects[0][0]
# Out:
# ((1227.0, 534.0), (88.0, 134.0), -0.0)

# %%
box = box.astype(int)

# %%
box[1][1]
# Out:
# 467

# %%
box[0][1]
# Out:
# 601.0

# %%
box[0][0]
# Out:
# 1183.0

# %%
box[2][0]
# Out:
# 1271.0

# %%
box = cv2.boxPoints(rects[0])

# %%
plt.imshow(image[box[1][1]:box[0][1],box[0][0]:box[2][0], :])

# %%
plt.imshow(image[467:601, 1183:1271, :])

# %%
image.shape
# Out:
# (640, 1280, 3)

# %%
plt.imshow(image)

# %%
plt.imshow(image[:-4, :99])

# %%
image[rects[1][1][0]:rects[1][0][0]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-4cd82b2e473d> in <module>
# ----> 1 image[rects[1][1][0]:rects[1][0][0]]
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
image.shape
# Out:
# (640, 1280, 3)

# %%
for rect in rects:
    plt.figure()
    card = image[rect[1]:rect[1]+rect[3],rect[0]:rect[0]+rect[2]]
    edge_card = cv2.Canny(card, 170, 200)
    plt.imshow(edge_card,cmap="gray")
# Out:
# (88.0, 134.0)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-29-5a8e793c29f2> in <module>
#       2     plt.figure()
#       3     print(rect[1])
# ----> 4     card = image[rect[1]:rect[1]+rect[3],rect[0]:rect[0]+rect[2]]
#       5     edge_card = cv2.Canny(card, 170, 200)
#       6     plt.imshow(edge_card,cmap="gray")
#
# IndexError: tuple index out of range

# %%
plt.figure(figsize=(20,10))
plt.imshow(img)

# %%
plt.figure(figsize=(20,10))
plt.imshow(im_bw)

# %%
image = cv2.imread('PlayingCards_52.png')
image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
im_bw = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
thresh, im_bw = cv2.threshold(im_bw, 170, 255, 0)
contours, hierarchy = cv2.findContours(im_bw.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

rects = [cv2.minAreaRect(each) for each in contours]
rects = [(a,b,c) for a, b, c  in rects if ((b[0]*b[1]>5000))]
img = image.copy()

box = cv2.boxPoints(rects[0])
box = box.astype('int')
img = cv2.drawContours(img, [box], -1, (0,255,0), 4)

plt.figure(figsize=(20,10))
plt.imshow(img)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-2-3e70abe89543> in <module>
#       1 image = cv2.imread('heart3.jpg')
# ----> 2 image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
#       3 im_bw = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
#       4 thresh, im_bw = cv2.threshold(im_bw, 170, 255, 0)
#       5 contours, hierarchy = cv2.findContours(im_bw.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#
# error: OpenCV(4.1.1) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'

# %%
contours, hierarchy = cv2.findContours(im_bw.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

rects = [cv2.minAreaRect(each) for each in contours]
rects = [(a,b,c) for a, b, c  in rects if ((b[0]*b[1]>5000))]
img = image.copy()
col = 0
for rect in rects:
    col +=20
    box = cv2.boxPoints(rect)
    box = box.astype('int')
    img = cv2.drawContours(img, [box], -1, (255, 255- col, 255- col), 5)
plt.figure(figsize=(20,10))
plt.imshow(img)
