# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('cards.png')

# %%
plt.figure(figsize=(15,50))
plt.imshow(img)
plt.show()

# %%
plt.figure(figsize=(15,50))
plt.imshow(img[:-4, :99])
plt.show()

# %%
img_new = img[:-4, :99]

# %%
cv2.imwrite('cards_new.jpg',img_new)
# Out:
# True
