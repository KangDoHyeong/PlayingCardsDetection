# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def edge_detect(image, tresh_min, tresh_max):
    f = plt.figure(figsize=(15,30))
    ax = f.add_subplot(131)
    ax2 = f.add_subplot(132)
    ax3 = f.add_subplot(133)
    
    im_bw = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    thresh, im_bw = cv2.threshold(im_bw, tresh_min, tresh_max, 0)

    
#     cv2.imwrite('bw_'+file_name, im_bw)

    contours, hierarchy = cv2.findContours(im_bw, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
    ax.imshow(image, cmap='Greys')
    cv2.drawContours(image, contours, -1, (0,255,0), 3)
    
    ax2.imshow(im_bw, cmap='gray')
    ax3.imshow(image)
    return len(contours)
#     cv2.imwrite('cnt_'+file_name, image)

# %%
img = cv2.imread('cards.png')
edge_detect(img, 110, 255)
# Out:
# 554

# %%
thresh, img_bin = cv2.threshold(img_gray, 90, 255, 0)
contours, hierarchy = cv2.findContours(img_bin, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
rects = [cv2.minAreaRect(each) for each in contours]
img_copy = img.copy()

box = cv2.boxPoints(rects[0])
box = box.astype('int')
img_copy = cv2.drawContours(img_copy, [box], -1, (0,0,255), 4)

plt.figure(figsize=(10,30))
plt.imshow(img_copy)
print(len(contours))
# Out:
# 811

# %%
img = cv2.imread('cards.png')
img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
for i in contours:
    print(i.shape)
# Out:
# (30, 1, 2)
# (54, 1, 2)
# (56, 1, 2)
# (49, 1, 2)
# (48, 1, 2)
# (56, 1, 2)
# (44, 1, 2)
# (2, 1, 2)
# (6, 1, 2)
# (13, 1, 2)
# (16, 1, 2)
# (8, 1, 2)
# (41, 1, 2)
# (31, 1, 2)
# (37, 1, 2)
# (1, 1, 2)
# (34, 1, 2)
# (34, 1, 2)
# (6, 1, 2)
# (8, 1, 2)
# (4, 1, 2)
# (4, 1, 2)
# (4, 1, 2)
# (4, 1, 2)
# (6, 1, 2)
# (4, 1, 2)
# (4, 1, 2)
# (24, 1, 2)
# (1, 1, 2)
# (4, 1, 2)
# (6, 1, 2)
# (6, 1, 2)
# (6, 1, 2)
# (4, 1, 2)
# (2, 1, 2)
# (7, 1, 2)
# (10, 1, 2)
# (6, 1, 2)
# (4, 1, 2)
# (4, 1, 2)
# (1, 1, 2)
# (15, 1, 2)
# (4, 1, 2)
# (6, 1, 2)
# (4, 1, 2)
# (4, 1, 2)
# (4, 1, 2)
# (6, 1, 2)
# (4, 1, 2)
# (4, 1, 2)
# (4, 1, 2)
# (6, 1, 2)
# (27, 1, 2)
# (4, 1, 2)
# (4, 1, 2)
# (6, 1, 2)
# (1, 1, 2)
# (4, 1, 2)
# (2, 1, 2)
# (2, 1, 2)
# (1, 1, 2)
# (1, 1, 2)
# (2, 1, 2)
# (4, 1, 2)
# (4, 1, 2)
# (4, 1, 2)
# (6, 1, 2)
# (1, 1, 2)
# (1, 1, 2)
# (1, 1, 2)
# (4, 1, 2)
# (20, 1, 2)
# (1, 1, 2)
# (4, 1, 2)
# (1, 1, 2)
# (1, 1, 2)
# (1, 1, 2)
# (1, 1, 2)
# (1, 1, 2)
# (2, 1, 2)
# (1, 1, 2)
# ...

# %%
thresh, img = cv2.threshold(img, 170, 255, 0)
contours, hierarchy = cv2.findContours(img, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
rects = [cv2.minAreaRect(each) for each in contours]
img_copy = img.copy()

box = cv2.boxPoints(rects[0])
box = box.astype('int')
img_copy = cv2.drawContours(img_copy, [box], -1, (0,255,0), 4)

plt.figure(figsize=(10,30))
plt.imshow(img_copy,cmap=('gray'))

# %%
len(contours)
# Out:
# 756

# %%
contours
# Out:
# [array([[[ 90, 986]],
#
#         [[ 89, 987]],
#
#         [[ 89, 990]],
#
#         [[ 90, 991]],
#
#         [[ 93, 991]],
#
#         [[ 94, 990]],
#
#         [[ 96, 990]],
#
#         [[ 96, 988]],
#
#         [[ 95, 988]],
#
#         [[ 94, 987]],
#
#         [[ 94, 986]]], dtype=int32), array([[[  4, 909]],
#
#         [[  5, 910]],
#
#         [[  7, 910]],
#
#         [[  8, 909]]], dtype=int32), array([[[  2, 897]],
#
#         [[  2, 902]],
#
#         [[  3, 901]],
#
#         [[  3, 898]]], dtype=int32), array([[[ 90, 883]],
#
#         [[ 90, 887]],
#
#         [[ 92, 887]],
#
#         [[ 92, 884]],
#
#         [[ 91, 884]]], dtype=int32), array([[[ 40, 883]]], dtype=int32), array([[[ 91, 881]],
#
#         [[ 92, 882]],
#
#         [[ 92, 881]]], dtype=int32), array([[[ 38, 879]]], dtype=int32), array([[[ 52, 870]],
#
#         [[ 51, 871]]], dtype=int32), array([[[ 50, 869]]], dtype=int32), array([[[ 54, 867]]], dtype=int32), array([[[ 36, 864]],
#
# ...
