# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
data_loc = '../dataset/'
imglist = []
for i in os.listdir(data_loc+'card_deck1'):
    tmpimg = cv2.imread(data_loc+'card_deck1/'+i, cv2.IMREAD_GRAYSCALE)
    tmpimg = cv2.resize(tmpimg, (96, 128), interpolation=cv2.INTER_AREA)
    imglist.append(tmpimg)
imglist = np.array(imglist)
wid, hei = 96, 128

# %%
CK = cv2.imread('CK.jpg', cv2.IMREAD_GRAYSCALE)
CK = cv2.resize(CK, (96, 128), interpolation=cv2.INTER_AREA)

# %%
plt.imshow(CK,cmap='gray')
plt.show()

# %%
plt.imshow(CK[120:,:], cmap='gray')

# %%
int(wid/10)
# Out:
# 9

# %%
CK[120:,:]
# Out:
# array([[170, 175, 178, 181, 178, 177, 180, 179, 180, 180, 180, 180, 180,
#         181, 181, 181, 180, 180, 180, 180, 180, 180, 180, 180, 180, 179,
#         180, 179, 178, 178, 176, 175, 181, 181, 181, 181, 181, 180, 180,
#         180, 180, 181, 181, 181, 181, 180, 180, 181, 182, 182, 182, 182,
#         182, 181, 181, 182, 183, 182, 182, 181, 180, 180, 178, 179, 179,
#         179, 179, 179, 178, 178, 177, 178, 178, 178, 179, 179, 179, 179,
#         180, 179, 175, 182, 183, 178, 126,  63,  95, 162, 179, 176,  50,
#         113, 175, 183, 179,  23],
#        [169, 173, 175, 178, 176, 175, 178, 176, 176, 177, 177, 177, 176,
#         177, 178, 178, 177, 178, 178, 178, 177, 177, 176, 177, 177, 177,
#         177, 176, 176, 176, 174, 173, 178, 179, 179, 179, 178, 179, 179,
#         179, 178, 178, 179, 179, 179, 179, 178, 179, 179, 179, 178, 178,
#         178, 178, 177, 178, 178, 178, 178, 177, 176, 176, 174, 173, 173,
# ...

# %%
cv2.threshold(CK, 25, 255, cv2. THRESH_BINARY_INV)

# %%
height, width = CK.shape
matrix = cv2.getRotationMatrix2D((width/2, height/2), 90, 1)
dst = cv2.warpAffine(CK, matrix, (width, height))

# %%
plt.imshow(dst)

# %%
height, width = CK.shape
matrix = cv2.getRotationMatrix2D((width/2, height/2), 90, 1)
dst = cv2.warpAffine(CK, matrix, (200, 200))
plt.imshow(dst)

# %%
height, width = CK.shape
matrix = cv2.getRotationMatrix2D((0, 0), 0, 1)
dst = cv2.warpAffine(CK, matrix, (200, 200))
plt.imshow(dst)

# %%
height, width = CK.shape
matrix = cv2.getRotationMatrix2D((100, 100), 180, 1)
dst = cv2.warpAffine(CK, matrix, (200, 200))
plt.imshow(dst)

# %%
matrix
# Out:
# array([[ 1.2246468e-16,  2.0000000e+00, -8.0000000e+01],
#        [-2.0000000e+00,  1.2246468e-16,  1.6000000e+02]])

# %%
peri = cv2.arcLength(CK,True)
approx = cv2.approxPolyDP(contour,0.01*peri,True)
pts = np.float32(approx)
qCard.corner_pts = pts
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-38-37c4c87ad60a> in <module>
# ----> 1 peri = cv2.arcLength(CK,True)
#       2 approx = cv2.approxPolyDP(contour,0.01*peri,True)
#       3 pts = np.float32(approx)
#       4 qCard.corner_pts = pts
#
# error: OpenCV(4.1.1) C:\projects\opencv-python\opencv\modules\imgproc\src\shapedescr.cpp:239: error: (-215:Assertion failed) count >= 0 && (depth == CV_32F || depth == CV_32S) in function 'cv::arcLength'

# %%
height, width = CK.shape
matrix = cv2.getRotationMatrix2D((width/2, height/2), -150/360, 1)
dst = cv2.warpAffine(CK, matrix, (width, height))
plt.imshow(dst)
