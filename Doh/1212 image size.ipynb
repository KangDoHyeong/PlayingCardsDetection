# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os, math

# %%
img = cv2.imread('spade10.jpg', )
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray, cmap='gray')

# %%
gray.shape
# Out:
# (666, 477)

# %%
x = np.zeros([666+10,477+10])

# %%
x[1:667, 1:478] = gray

# %%
plt.imshow(x)

# %%
img = cv2.imread('../dataset/card_deck1/C2.jpg')
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
gray.shape
# Out:
# (120, 100)

# %%
x = np.zeros([120+50,100+50])
x[0+25:170-25, 0+25:150-25] = gray

plt.imshow(x, cmap='gray')

# %%
height, width = gray.shape
matrix = cv2.getRotationMatrix2D((75, 75), 10, 1)
dst = cv2.warpAffine(gray, matrix, (150, 150))
plt.imshow(dst)

# %%
x = np.zeros([120+50,100+50])
x[0+25:170-25, 0+25:150-25] = gray

# %%
dataloc='../dataset/card_deck1'

# %%
x = np.zeros([120+50,100+50])
for i in os.listdir(dataloc):
    img = cv2.imread(dataloc+'i')
    x[0+25:170-25, 0+25:150-25] = img
    cv2.imwrite('../''cnt_'+file_name, image)
# Out:
# ['C10.jpg',
#  'C2.jpg',
#  'C3.jpg',
#  'C4.jpg',
#  'C5.jpg',
#  'C6.jpg',
#  'C7.jpg',
#  'C8.jpg',
#  'C9.jpg',
#  'CA.jpg',
#  'CJ.jpg',
#  'CK.jpg',
#  'CQ.jpg',
#  'D10.jpg',
#  'D2.jpg',
#  'D3.jpg',
#  'D4.jpg',
#  'D5.jpg',
#  'D6.jpg',
#  'D7.jpg',
#  'D8.jpg',
#  'D9.jpg',
#  'DA.jpg',
#  'DJ.jpg',
#  'DK.jpg',
#  'DQ.jpg',
#  'H10.jpg',
#  'H2.jpg',
#  'H3.jpg',
#  'H4.jpg',
#  'H5.jpg',
#  'H6.jpg',
#  'H7.jpg',
#  'H8.jpg',
#  'H9.jpg',
#  'HA.jpg',
#  'HJ.jpg',
#  'HK.jpg',
#  'HQ.jpg',
#  'S10.jpg',
#  'S2.jpg',
#  'S3.jpg',
#  'S4.jpg',
#  'S5.jpg',
#  'S6.jpg',
#  'S7.jpg',
#  'S8.jpg',
#  'S9.jpg',
#  'SA.jpg',
#  'SJ.jpg',
#  'SK.jpg',
#  'SQ.jpg']
