# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os, math

# %%
img = cv2.imread('spade10.jpg', )
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(gray, cmap='gray')

# %%
gray.shape
# Out:
# (666, 477)

# %%
x = np.zeros([666+10,477+10])

# %%
x[1:667, 1:478] = gray

# %%
x = np.zeros([120+50,100+50])
x[0+25:170-25, 0+25:150-25] = gray

plt.imshow(x, cmap='gray')

# %%
height, width = gray.shape
matrix = cv2.getRotationMatrix2D((75, 75), 10, 1)
dst = cv2.warpAffine(gray, matrix, (150, 150))
plt.imshow(dst)

# %%
x = np.zeros([120+50,100+50])
x[0+25:170-25, 0+25:150-25] = gray

# %%
dataloc='../dataset/card_deck1/'

# %%
x = np.zeros([120+50,100+50])
for i in os.listdir(dataloc):
    print(i)
    img = cv2.imread(dataloc+i)
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    x[0+25:170-25, 0+25:150-25] = gray
    cv2.imwrite('../big_dataset/'+i, x)
# Out:
# C10.jpg
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-11-044acff6820e> in <module>
#       3     print(i)
#       4     img = cv2.imread(dataloc+'/i')
# ----> 5     gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
#       6     x[0+25:170-25, 0+25:150-25] = gray
#       7     cv2.imwrite('../big_dataset/'+i, x)
#
# error: OpenCV(4.1.1) C:\projects\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
