# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('cards.png')
im_bw = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
thresh, im_bw = cv2.threshold(im_bw, 170, 255, 0)

contours, hierarchy = cv2.findContours(im_bw.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

rects = [cv2.boundingRect(each) for each in contours]
rects = [(x,y,w,h) for (x,y,w,h) in rects if ((w*h>1000))]

image1 = image.copy()
for rect in rects:
    # Draw the rectangles
    cv2.rectangle(image1, (rect[0], rect[1]), 
                  (rect[0] + rect[2], rect[1] + rect[3]), (255, 0, 0), 5) 

plt.figure(figsize=(15,12))
plt.imshow(image1)

# %%
img = cv2.imread('cards.png', cv2.IMREAD_GRAYSCALE)
edge1 = cv2.Canny(img, 50, 200)
edge2 = cv2.Canny(img, 100, 200)
edge3 = cv2.Canny(img, 170, 200)

plt.figure(figsize=(20,10))
plt.imshow(edge1, cmap="gray")
plt.figure(figsize=(20,10))
plt.imshow(edge2, cmap="gray")
plt.figure(figsize=(20,10))
plt.imshow(edge3, cmap="gray")

# %%
img = cv2.imread('cards.png', cv2.IMREAD_GRAYSCALE)
edge4 = cv2.Canny(img, 60, 140)
plt.figure(figsize=(20,10))
plt.imshow(edge4, cmap="gray")

# %%
contours, hierarchy = cv2.findContours(edge1.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
img1=img.copy()
cv2.drawContours(img, contours, -1, (255,255, 255), 3)
plt.figure(figsize=(20,10))
plt.imshow(img1)#, cmap="gray")

# %%
rects = [cv2.boundingRect(each) for each in contours]
rects = [(x,y,w,h) for (x,y,w,h) in rects if ((w*h>1000))]

for rect in rects:
    # Draw the rectangles
    cv2.rectangle(img1, (rect[0], rect[1]), 
                  (rect[0] + rect[2], rect[1] + rect[3]), (0, 0, 255), 5) 

plt.figure(figsize=(15,12))
plt.imshow(img1)

# %%
rects
# Out:
# [(0, 897, 67, 210),
#  (46, 865, 49, 25),
#  (7, 832, 40, 52),
#  (5, 792, 83, 93),
#  (0, 782, 98, 325),
#  (1, 765, 99, 18),
#  (0, 650, 98, 115),
#  (1, 650, 97, 115),
#  (24, 547, 41, 26),
#  (8, 534, 78, 79),
#  (0, 387, 98, 262),
#  (1, 387, 97, 116),
#  (3, 211, 62, 26),
#  (8, 147, 78, 91),
#  (0, 0, 104, 1109),
#  (0, 0, 100, 379),
#  (1, 264, 97, 115),
#  (1, 10, 97, 114)]

# %%
for rect in rects:
    aspect_ratio = float(rect[2])/rect[3]
    print(aspect_ratio)
# Out:
# 0.319047619047619
# 1.96
# 0.7692307692307693
# 0.8924731182795699
# 0.30153846153846153
# 5.5
# 0.8521739130434782
# 0.8434782608695652
# 1.5769230769230769
# 0.9873417721518988
# 0.37404580152671757
# 0.8362068965517241
# 2.3846153846153846
# 0.8571428571428571
# 0.09377817853922453
# 0.2638522427440633
# 0.8434782608695652
# 0.8508771929824561

# %%
rect=rects[3]
imgimg=img.copy()
cv2.rectangle(imgimg, (rect[0], rect[1]), 
              (rect[0] + rect[2], rect[1] + rect[3]), (0, 0, 255), 5) 

plt.figure(figsize=(15,12))
plt.imshow(imgimg, cmap="gray")

# %%
rect=rects[7]
imgimg=img.copy()
cv2.rectangle(imgimg, (rect[0], rect[1]), 
              (rect[0] + rect[2], rect[1] + rect[3]), (255, 255, 255), 5) 

plt.figure(figsize=(15,12))
plt.imshow(imgimg, cmap="gray")

# %%
rect=rects[6]
imgimg=img.copy()
cv2.rectangle(imgimg, (rect[0], rect[1]), 
              (rect[0] + rect[2], rect[1] + rect[3]), (255, 255, 255), 5) 

plt.figure(figsize=(15,12))
plt.imshow(imgimg, cmap="gray")

# %%
rects = [cv2.boundingRect(each) for each in contours]
rects2 = [(x,y,w,h) for (x,y,w,h) in rects if ((w>=95)&(w<=100)&(h>=113)&(h<=117))]
imgimg=img.copy()
for rect in rects2:
    # Draw the rectangles
    cv2.rectangle(imgimg, (rect[0], rect[1]), 
                  (rect[0] + rect[2], rect[1] + rect[3]), (255, 255, 255), 5) 

plt.figure(figsize=(15,12))
plt.imshow(imgimg,cmap="gray")

# %%
rects2
# Out:
# [(0, 650, 98, 115),
#  (1, 650, 97, 115),
#  (1, 387, 97, 116),
#  (1, 264, 97, 115),
#  (1, 10, 97, 114)]

# %%
rects[3]
# Out:
# (5, 792, 83, 93)

# %%
contours
# Out:
# [array([[[  98, 1106]]], dtype=int32),
#  array([[[  13, 1095]]], dtype=int32),
#  array([[[  89, 1092]],
#
#         [[  90, 1092]]], dtype=int32),
#  array([[[  89, 1089]],
#
#         [[  87, 1091]],
#
#         [[  86, 1090]],
#
#         [[  85, 1091]],
#
#         [[  84, 1091]],
#
#         [[  84, 1093]],
#
#         [[  85, 1094]],
#
#         [[  86, 1094]],
#
#         [[  87, 1095]],
#
#         [[  87, 1097]],
#
#         [[  91, 1097]],
#
#         [[  92, 1096]],
#
#         [[  91, 1095]],
#
#         [[  92, 1094]],
#
#         [[  94, 1094]],
#
#         [[  95, 1093]],
#
#         [[  95, 1091]],
#
#         [[  92, 1091]],
#
#         [[  94, 1091]],
#
#         [[  95, 1092]],
#
#         [[  93, 1094]],
#
#         [[  92, 1094]],
#
#         [[  91, 1095]],
#
#         [[  91, 1096]],
#
#         [[  90, 1097]],
#
#         [[  88, 1097]],
#
#         [[  87, 1096]],
#
#         [[  87, 1094]],
#
#         [[  86, 1094]],
#
#         [[  84, 1092]],
#
# ...

# %%
c0 = contours[3]
M = cv2.moments(c0)
M
# Out:
# {'m00': 6.5,
#  'm10': 591.1666666666666,
#  'm01': 5754.833333333333,
#  'm20': 53768.08333333333,
#  'm11': 523395.2916666666,
#  'm02': 5095099.416666666,
#  'm30': 4890544.55,
#  'm21': 47604160.15,
#  'm12': 463393782.51666665,
#  'm03': 4511002757.45,
#  'mu20': 2.2329059829062317,
#  'mu11': 0.577991452999413,
#  'mu02': 6.079059829004109,
#  'mu30': 0.14440061431378126,
#  'mu21': -0.09841113064499041,
#  'mu12': -0.7102673257915058,
#  'mu03': -0.6473588943481445,
#  'nu20': 0.052849845749259924,
#  'nu11': 0.013680271076909185,
#  'nu02': 0.1438830728758369,
#  'nu30': 0.0013405581250082045,
#  'nu21': -0.0009136099690733456,
#  'nu12': -0.006593840608244428,
#  'nu03': -0.006009823640562657}

# %%
cv2.contourArea(c0)
# Out:
# 6.5

# %%
cv2.arcLength(c0, closed=True), cv2.arcLength(c0, closed=False)
# Out:
# (11.41421353816986, 10.0)

# %%
cx = int(M['m10'] / M['m00'])
cy = int(M['m01'] / M['m00'])
leftmost = tuple(c0[c0[:, :, 0].argmin()][0])
rightmost = tuple(c0[c0[:, :, 0].argmax()][0])
topmost = tuple(c0[c0[:, :, 1].argmin()][0])
bottommost = tuple(c0[c0[:, :, 1].argmax()][0])

plt.subplot(1,2,1)
plt.imshow(image, cmap='bone')
plt.title("center point")
plt.axis('off')
plt.scatter([cx], [cy], c="r", s=30)

plt.subplot(1,2,2)
plt.imshow(image, cmap='bone')
plt.axis("off")
plt.scatter(
    [leftmost[0], rightmost[0], topmost[0], bottommost[0]], 
    [leftmost[1], rightmost[1], topmost[1], bottommost[1]], 
    c="b", s=30)
plt.title("Extream Points")

plt.show()

# %%
img1 = image.copy().astype('uint8')
img2 = image.copy().astype('uint8')
img3 = image.copy().astype('uint8')

c0 = contours[2]

epsilon1 = 0.01*cv2.arcLength(c0, True)
epsilon2 = 0.05*cv2.arcLength(c0, True)

approx1 = cv2.approxPolyDP(c0, epsilon1, True)
approx2 = cv2.approxPolyDP(c0, epsilon2, True)

image1 = cv2.drawContours(img1, [c0], -1, 7)  #
image2 = cv2.drawContours(img2, [approx1], -1, 7)
image3 = cv2.drawContours(img3, [approx2], -1, 7)

titles = ['Original', '$\epsilon=0.01$', '$\epsilon=0.05$']
images = [image1, image2, image3]

for i in range(3):
    #plt.subplot(1, 3, i+1)
    plt.figure(figsize=(10,20))
    plt.title(titles[i])
    plt.imshow(images[i], cmap='gray')
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
img4 = image.copy().astype('uint8')

c0 = contours[0]
hull = cv2.convexHull(c0)
image4 = cv2.drawContours(img4, [hull], 0, 3)
titles = ['원본 이미지', 'Convex Hull']
images = [image, img4]

for i in range(2):
    #plt.subplot(1, 2, i+1)
    plt.figure(figsize=(20,10))
    plt.title(titles[i])
    plt.imshow(images[i], 'gray')
    plt.axis('off')

plt.show()

# %%
contours, hierarchy = cv2.findContours(edge2.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
rects = [cv2.boundingRect(each) for each in contours]
rects2 = [(x,y,w,h) for (x,y,w,h) in rects if ((w>=95)&(w<=100)&(h>=113)&(h<=117))]
imgimg=img.copy()
for rect in rects2:
    # Draw the rectangles
    cv2.rectangle(imgimg, (rect[0], rect[1]), 
                  (rect[0] + rect[2], rect[1] + rect[3]), (255, 255, 255), 5) 

plt.figure(figsize=(15,12))
plt.imshow(imgimg,cmap="gray")

# %%
contours, hierarchy = cv2.findContours(edge3.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
rects = [cv2.boundingRect(each) for each in contours]
rects2 = [(x,y,w,h) for (x,y,w,h) in rects if ((w>=95)&(w<=100)&(h>=113)&(h<=117))]
imgimg=img.copy()
for rect in rects2:
    # Draw the rectangles
    cv2.rectangle(imgimg, (rect[0], rect[1]), 
                  (rect[0] + rect[2], rect[1] + rect[3]), (255, 255, 255), 5) 

plt.figure(figsize=(15,12))
plt.imshow(imgimg,cmap="gray")
