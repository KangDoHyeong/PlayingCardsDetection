# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread('cards_new.jpg', cv2.IMREAD_GRAYSCALE)
edge3 = cv2.Canny(img, 170, 200)

# %%
plt.figure(figsize=(30,20))
plt.imshow(edge3, cmap="gray")

# %%
contours, hierarchy = cv2.findContours(edge3.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
rects = [cv2.boundingRect(each) for each in contours]
rects2 = [(x,y,w,h) for (x,y,w,h) in rects if ((w>=95)&(w<=100)&(h>=113)&(h<=117))]
imgimg=img.copy()
for rect in rects2:
    # Draw the rectangles
    cv2.rectangle(imgimg, (rect[0], rect[1]), 
                  (rect[0] + rect[2], rect[1] + rect[3]), (255, 255, 255), 5) 

plt.figure(figsize=(15,12))
plt.imshow(imgimg,cmap="gray")

# %%
plt.figure()
rect = rects2[0]
img2=img.copy()
card = img2[rect[1]:rect[1]+rect[3],rect[0]:rect[0]+rect[2]]
edge_card = cv2.Canny(card, 170, 200)
plt.imshow(edge_card,cmap="gray")

# %% [markdown]
# ### 카드? 네모상자?를 뽑고 다시 그 안에서 contour 찾기

# %%
contours, hierarchy = cv2.findContours(edge_card.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
rects = [cv2.boundingRect(each) for each in contours]
rects = [(x,y,w,h) for (x,y,w,h) in rects if w*h>100]
imgimg=edge_card.copy()
for rect in rects:
    # Draw the rectangles
    cv2.rectangle(imgimg, (rect[0], rect[1]), 
                  (rect[0] + rect[2], rect[1] + rect[3]), (255, 255, 255), 1) 

plt.figure(figsize=(15,12))
plt.imshow(imgimg,cmap="gray")

# %%
rects
# Out:
# [(84, 98, 11, 14),
#  (58, 85, 25, 20),
#  (58, 85, 25, 20),
#  (5, 84, 24, 21),
#  (5, 84, 24, 21),
#  (32, 67, 25, 20),
#  (32, 67, 25, 20),
#  (59, 48, 25, 21),
#  (59, 48, 25, 21),
#  (6, 48, 25, 21),
#  (6, 48, 25, 20),
#  (34, 30, 24, 21),
#  (34, 30, 24, 21),
#  (61, 13, 24, 21),
#  (61, 15, 24, 19),
#  (7, 12, 25, 21),
#  (7, 12, 25, 21),
#  (0, 0, 98, 115)]

# %%
imgimg=edge_card.copy()
rect = rects[0]
cv2.rectangle(imgimg, (rect[0], rect[1]), 
            (rect[0] + rect[2], rect[1] + rect[3]), (255, 255, 255), 1) 

plt.figure(figsize=(15,12))
plt.imshow(imgimg,cmap="gray")

# %% [markdown]
# ### 8을 뽑아내긴 했는데 알아볼 수 있을까?

# %%
card_fig = card[rect[1]:rect[1]+rect[3],rect[0]:rect[0]+rect[2]]
plt.imshow(card_fig, cmap="gray")

# %%
imgimg=edge_card.copy()
rect = rects[1]
cv2.rectangle(imgimg, (rect[0], rect[1]), 
            (rect[0] + rect[2], rect[1] + rect[3]), (255, 255, 255), 1) 

plt.figure(figsize=(15,12))
plt.imshow(imgimg,cmap="gray")
card_fig = card[rect[1]:rect[1]+rect[3],rect[0]:rect[0]+rect[2]]
plt.imshow(card_fig, cmap="gray")

# %% [markdown]
# ## 전처리 고민은 여기서 멈추고 학습에 대한 고민을 내일 만나서 진행해요!!

# %% [markdown]
# ### 번외 - 월욜에 찍은 카드에다 필터 적용해보기

# %% [markdown]
# (그림이 너무 이쁘다)

# %%
img = cv2.imread('card3.jpg', cv2.IMREAD_GRAYSCALE)
edge4 = cv2.Canny(img, 180, 200)
plt.figure(figsize=(30,20))
plt.imshow(edge4, cmap="gray")

# %% [markdown]
# (이건 좀있다가 작업하겟음)

# %%
contours, hierarchy = cv2.findContours(edge4.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
rects = [cv2.boundingRect(each) for each in contours]
#rects2 = [(x,y,w,h) for (x,y,w,h) in rects if ((w>=95)&(w<=100)&(h>=113)&(h<=117))]
imgimg=img.copy()
for rect in rects:
    # Draw the rectangles
    cv2.rectangle(imgimg, (rect[0], rect[1]), 
                  (rect[0] + rect[2], rect[1] + rect[3]), (255, 255, 255), 5) 

plt.figure(figsize=(15,12))
plt.imshow(imgimg,cmap="gray")
